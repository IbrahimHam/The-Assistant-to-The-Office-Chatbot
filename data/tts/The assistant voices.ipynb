# %%
import os

# %%
os.environ["TORCH_FORCE_NO_WEIGHTS_ONLY_LOAD"] = "1"

# %%
import os
from TTS.api import TTS
import torch
from TTS.tts.configs.xtts_config import XttsConfig
from TTS.tts.models.xtts import XttsAudioConfig
from TTS.config.shared_configs import BaseDatasetConfig

# Allowlist the required classes for safe unpickling
torch.serialization.add_safe_globals([XttsConfig, XttsAudioConfig, BaseDatasetConfig])

# Initialize the TTS model
tts = TTS("tts_models/multilingual/multi-dataset/xtts_v2", gpu=False)

# Path to the specific .wav file
wav_file = "Michael_2.wav"

if not os.path.isfile(wav_file):
    print(f"No such file: {wav_file}")
else:
    print(f"Processing: {wav_file}")
    tts.tts_to_file(
        text="This voice seems to work better than the other one.",
        file_path=f"output_{os.path.basename(wav_file)}",
        speaker_wav=wav_file,
        language="en"
    )
# Out:
#  > tts_models/multilingual/multi-dataset/xtts_v2 is already downloaded.
#  > Using model: xtts
# Processing: Michael_2.wav
#  > Text splitted to sentences.
# ['This voice seems to work better than the other one.']
#  > Processing time: 6.259562969207764
#  > Real-time factor: 1.7968048775129035
